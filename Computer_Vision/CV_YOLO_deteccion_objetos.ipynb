# %% [markdown]
# #### Documentacion YOLO 11 https://docs.ultralytics.com/es/tasks/detect/#models

# %%
import cv2
import time
import numpy as np
from ultralytics import YOLO

# Cargar el modelo YOLOv11 (para detección de objetos)
model = YOLO("yolo11n.pt")

# Definir la fuente de video 
cap = cv2.VideoCapture(0) # En directo
# video_path = './rutadelvideo'
# cap = cv2.VideoCapture(video_path) # De un archivo 

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Medir el tiempo de procesamiento para calcular la latencia
    start_time = time.time()
    
    # Realizar la detección (el modelo de segmentación también hace detección)
    results = model(
        frame, 
        conf=0.7, # solo muestra lo que esta seguro al 70%
        # classes=[0] # Si solo quieres detectar ciertas clases, por ejemplo, 'persona' (clase 0)
    )
    latency = (time.time() - start_time) * 1000  # Latencia en milisegundos

    # Acceder a las detecciones (bounding boxes)
    boxes_obj = results[0].boxes
    if boxes_obj is not None and len(boxes_obj) > 0:
        bboxes = boxes_obj.xyxy.cpu().numpy()    # Coordenadas [x1, y1, x2, y2]
        confs = boxes_obj.conf.cpu().numpy()      # Puntajes de confianza
        classes = boxes_obj.cls.cpu().numpy()     # Índices de clase
        
        # Iterar sobre cada detección y dibujar el bounding box y la etiqueta
        for i, box in enumerate(bboxes):
            x1, y1, x2, y2 = map(int, box)
            
            # Obtener el nombre de la clase
            class_name = model.names[int(classes[i])] if hasattr(model, 'names') else str(int(classes[i]))
            
            # Crear la etiqueta con el nombre de la clase y la confianza
            label = f'{class_name} {confs[i]:.2f}'
            
            # Dibujar el bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2) # Rojo, grosor 2
            
            # Dibujar la etiqueta encima del bounding box
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

    # Mostrar la latencia en el frame
    cv2.putText(frame, f'Latency: {latency:.1f}ms', (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)

    # Mostrar el frame procesado en tiempo real
    cv2.imshow("YOLOv11 - Detección de Objetos", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 177.3ms
# Speed: 1.1ms preprocess, 177.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 193.2ms
# Speed: 2.0ms preprocess, 193.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.7ms
# Speed: 1.1ms preprocess, 180.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 186.4ms
# Speed: 1.1ms preprocess, 186.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 182.5ms
# Speed: 1.3ms preprocess, 182.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.5ms
# Speed: 1.3ms preprocess, 177.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 182.5ms
# Speed: 1.4ms preprocess, 182.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.0ms
# Speed: 1.2ms preprocess, 171.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.0ms
# Speed: 1.2ms preprocess, 172.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.6ms
# Speed: 1.1ms preprocess, 174.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.0ms
# Speed: 1.6ms preprocess, 173.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.9ms
# Speed: 1.2ms preprocess, 180.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.1ms
# Speed: 1.1ms preprocess, 175.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.2ms
# Speed: 1.4ms preprocess, 169.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.4ms
# Speed: 1.3ms preprocess, 171.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.9ms
# Speed: 1.4ms preprocess, 170.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.0ms
# Speed: 1.1ms preprocess, 175.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.2ms
# Speed: 1.4ms preprocess, 171.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.4ms
# Speed: 1.2ms preprocess, 166.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.2ms
# Speed: 1.9ms preprocess, 172.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 161.8ms
# Speed: 1.1ms preprocess, 161.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 183.3ms
# Speed: 1.1ms preprocess, 183.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.8ms
# Speed: 1.1ms preprocess, 167.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.1ms
# Speed: 1.2ms preprocess, 169.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.2ms
# Speed: 1.3ms preprocess, 168.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.5ms
# Speed: 1.3ms preprocess, 172.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.9ms
# Speed: 1.3ms preprocess, 170.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.2ms
# Speed: 1.2ms preprocess, 170.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.7ms
# Speed: 1.1ms preprocess, 168.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.3ms
# Speed: 1.3ms preprocess, 174.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.3ms
# Speed: 1.2ms preprocess, 172.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.0ms
# Speed: 1.1ms preprocess, 174.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.6ms
# Speed: 1.3ms preprocess, 177.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.3ms
# Speed: 1.2ms preprocess, 173.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.4ms
# Speed: 1.1ms preprocess, 174.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 176.1ms
# Speed: 1.2ms preprocess, 176.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 176.1ms
# Speed: 1.4ms preprocess, 176.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.4ms
# Speed: 1.4ms preprocess, 175.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.9ms
# Speed: 1.4ms preprocess, 172.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 171.9ms
# Speed: 1.2ms preprocess, 171.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.9ms
# Speed: 1.1ms preprocess, 171.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 182.7ms
# Speed: 1.3ms preprocess, 182.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.8ms
# Speed: 1.3ms preprocess, 175.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 174.4ms
# Speed: 1.2ms preprocess, 174.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 174.0ms
# Speed: 1.4ms preprocess, 174.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 175.2ms
# Speed: 1.4ms preprocess, 175.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 185.8ms
# Speed: 1.4ms preprocess, 185.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 173.6ms
# Speed: 1.3ms preprocess, 173.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 173.1ms
# Speed: 1.1ms preprocess, 173.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 174.8ms
# Speed: 1.2ms preprocess, 174.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 172.8ms
# Speed: 1.0ms preprocess, 172.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 183.9ms
# Speed: 1.3ms preprocess, 183.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 176.6ms
# Speed: 1.1ms preprocess, 176.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 173.2ms
# Speed: 1.3ms preprocess, 173.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.4ms
# Speed: 1.1ms preprocess, 177.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.9ms
# Speed: 1.3ms preprocess, 169.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.2ms
# Speed: 1.3ms preprocess, 177.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 179.1ms
# Speed: 1.3ms preprocess, 179.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.1ms
# Speed: 1.2ms preprocess, 175.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.6ms
# Speed: 1.1ms preprocess, 180.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.1ms
# Speed: 1.1ms preprocess, 180.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.1ms
# Speed: 1.1ms preprocess, 177.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.6ms
# Speed: 1.1ms preprocess, 177.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.0ms
# Speed: 1.6ms preprocess, 172.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.9ms
# Speed: 1.2ms preprocess, 170.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.6ms
# Speed: 1.4ms preprocess, 168.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.0ms
# Speed: 1.5ms preprocess, 169.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.3ms
# Speed: 1.2ms preprocess, 172.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 175.2ms
# Speed: 1.3ms preprocess, 175.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.4ms
# Speed: 1.3ms preprocess, 175.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 183.7ms
# Speed: 1.4ms preprocess, 183.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.6ms
# Speed: 1.4ms preprocess, 172.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.6ms
# Speed: 1.4ms preprocess, 171.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.1ms
# Speed: 1.2ms preprocess, 171.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.0ms
# Speed: 1.2ms preprocess, 171.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.3ms
# Speed: 1.3ms preprocess, 164.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.9ms
# Speed: 1.1ms preprocess, 169.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.6ms
# Speed: 1.1ms preprocess, 172.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 165.9ms
# Speed: 1.1ms preprocess, 165.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.5ms
# Speed: 1.1ms preprocess, 166.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.2ms
# Speed: 1.6ms preprocess, 168.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.9ms
# Speed: 1.3ms preprocess, 168.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.5ms
# Speed: 1.4ms preprocess, 168.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.4ms
# Speed: 1.1ms preprocess, 168.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.8ms
# Speed: 1.2ms preprocess, 169.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.4ms
# Speed: 1.3ms preprocess, 168.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.8ms
# Speed: 1.4ms preprocess, 169.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.4ms
# Speed: 1.4ms preprocess, 168.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.4ms
# Speed: 1.3ms preprocess, 166.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.2ms
# Speed: 1.1ms preprocess, 167.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.9ms
# Speed: 1.1ms preprocess, 171.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.3ms
# Speed: 1.3ms preprocess, 173.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.9ms
# Speed: 1.2ms preprocess, 168.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.1ms
# Speed: 1.1ms preprocess, 164.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 181.0ms
# Speed: 1.2ms preprocess, 181.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.8ms
# Speed: 1.2ms preprocess, 172.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.5ms
# Speed: 1.4ms preprocess, 171.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.5ms
# Speed: 1.3ms preprocess, 162.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.2ms
# Speed: 1.0ms preprocess, 174.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 176.5ms
# Speed: 1.3ms preprocess, 176.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.2ms
# Speed: 1.4ms preprocess, 170.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.4ms
# Speed: 1.3ms preprocess, 171.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.5ms
# Speed: 1.3ms preprocess, 170.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.8ms
# Speed: 1.2ms preprocess, 171.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.1ms
# Speed: 1.4ms preprocess, 167.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.2ms
# Speed: 1.3ms preprocess, 166.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.7ms
# Speed: 1.2ms preprocess, 163.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.8ms
# Speed: 1.1ms preprocess, 170.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.7ms
# Speed: 1.5ms preprocess, 169.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.6ms
# Speed: 1.4ms preprocess, 167.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.8ms
# Speed: 1.2ms preprocess, 171.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.8ms
# Speed: 1.3ms preprocess, 169.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.0ms
# Speed: 1.3ms preprocess, 170.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.3ms
# Speed: 1.4ms preprocess, 169.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.0ms
# Speed: 1.1ms preprocess, 171.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 176.1ms
# Speed: 1.5ms preprocess, 176.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.5ms
# Speed: 1.4ms preprocess, 180.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.2ms
# Speed: 1.3ms preprocess, 171.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 187.8ms
# Speed: 1.2ms preprocess, 187.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 179.4ms
# Speed: 1.2ms preprocess, 179.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.1ms
# Speed: 1.2ms preprocess, 169.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.2ms
# Speed: 1.2ms preprocess, 174.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.4ms
# Speed: 1.4ms preprocess, 175.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.5ms
# Speed: 1.1ms preprocess, 170.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.5ms
# Speed: 1.2ms preprocess, 171.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.8ms
# Speed: 1.2ms preprocess, 170.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.0ms
# Speed: 1.1ms preprocess, 169.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.4ms
# Speed: 1.1ms preprocess, 172.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.3ms
# Speed: 1.4ms preprocess, 168.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.3ms
# Speed: 1.4ms preprocess, 169.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.6ms
# Speed: 1.3ms preprocess, 168.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.6ms
# Speed: 1.6ms preprocess, 171.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.0ms
# Speed: 1.3ms preprocess, 172.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.9ms
# Speed: 1.2ms preprocess, 180.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.6ms
# Speed: 1.1ms preprocess, 171.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.3ms
# Speed: 1.2ms preprocess, 170.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.4ms
# Speed: 1.2ms preprocess, 171.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.4ms
# Speed: 1.3ms preprocess, 169.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.5ms
# Speed: 1.2ms preprocess, 174.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.9ms
# Speed: 1.1ms preprocess, 173.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.8ms
# Speed: 1.3ms preprocess, 171.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 184.0ms
# Speed: 1.3ms preprocess, 184.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.4ms
# Speed: 1.2ms preprocess, 180.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.5ms
# Speed: 1.2ms preprocess, 169.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 176.9ms
# Speed: 1.4ms preprocess, 176.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 book, 175.4ms
# Speed: 1.1ms preprocess, 175.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.7ms
# Speed: 1.2ms preprocess, 170.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 book, 166.6ms
# Speed: 1.6ms preprocess, 166.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.6ms
# Speed: 1.4ms preprocess, 166.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.8ms
# Speed: 1.7ms preprocess, 171.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.6ms
# Speed: 1.2ms preprocess, 172.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.1ms
# Speed: 1.3ms preprocess, 175.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 book, 168.4ms
# Speed: 1.2ms preprocess, 168.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.3ms
# Speed: 1.4ms preprocess, 169.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.2ms
# Speed: 1.1ms preprocess, 172.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.0ms
# Speed: 1.2ms preprocess, 173.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.3ms
# Speed: 1.1ms preprocess, 166.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 176.4ms
# Speed: 1.3ms preprocess, 176.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 book, 172.2ms
# Speed: 1.4ms preprocess, 172.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 book, 177.7ms
# Speed: 1.3ms preprocess, 177.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 book, 175.6ms
# Speed: 1.3ms preprocess, 175.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.3ms
# Speed: 1.1ms preprocess, 167.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.0ms
# Speed: 1.4ms preprocess, 177.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.4ms
# Speed: 1.3ms preprocess, 169.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.9ms
# Speed: 1.3ms preprocess, 170.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.7ms
# Speed: 1.3ms preprocess, 171.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.5ms
# Speed: 1.1ms preprocess, 180.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.1ms
# Speed: 1.2ms preprocess, 174.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.7ms
# Speed: 1.1ms preprocess, 169.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.6ms
# Speed: 1.1ms preprocess, 169.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.4ms
# Speed: 1.2ms preprocess, 175.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.6ms
# Speed: 1.2ms preprocess, 173.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 175.9ms
# Speed: 1.4ms preprocess, 175.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 171.3ms
# Speed: 1.3ms preprocess, 171.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.2ms
# Speed: 1.1ms preprocess, 171.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.1ms
# Speed: 1.7ms preprocess, 167.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 176.8ms
# Speed: 1.3ms preprocess, 176.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 176.3ms
# Speed: 2.0ms preprocess, 176.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.2ms
# Speed: 1.1ms preprocess, 168.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.0ms
# Speed: 1.1ms preprocess, 168.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.8ms
# Speed: 1.3ms preprocess, 171.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.1ms
# Speed: 1.3ms preprocess, 169.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.2ms
# Speed: 1.1ms preprocess, 171.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.0ms
# Speed: 1.5ms preprocess, 172.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.2ms
# Speed: 1.2ms preprocess, 174.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 176.9ms
# Speed: 1.3ms preprocess, 176.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.8ms
# Speed: 1.4ms preprocess, 166.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.3ms
# Speed: 1.3ms preprocess, 174.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.1ms
# Speed: 1.3ms preprocess, 171.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.0ms
# Speed: 1.6ms preprocess, 169.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 185.4ms
# Speed: 1.1ms preprocess, 185.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.9ms
# Speed: 1.6ms preprocess, 171.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.9ms
# Speed: 1.4ms preprocess, 175.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 hair drier, 175.0ms
# Speed: 1.4ms preprocess, 175.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.7ms
# Speed: 1.5ms preprocess, 170.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.3ms
# Speed: 1.1ms preprocess, 167.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 178.6ms
# Speed: 1.2ms preprocess, 178.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.7ms
# Speed: 1.4ms preprocess, 166.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.3ms
# Speed: 1.1ms preprocess, 167.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.1ms
# Speed: 1.2ms preprocess, 175.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.4ms
# Speed: 1.3ms preprocess, 173.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.8ms
# Speed: 1.2ms preprocess, 175.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.2ms
# Speed: 1.3ms preprocess, 168.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.4ms
# Speed: 1.2ms preprocess, 175.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.8ms
# Speed: 1.2ms preprocess, 174.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.2ms
# Speed: 1.2ms preprocess, 167.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.1ms
# Speed: 1.1ms preprocess, 173.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.6ms
# Speed: 1.2ms preprocess, 173.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.4ms
# Speed: 1.2ms preprocess, 175.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.3ms
# Speed: 1.5ms preprocess, 172.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.9ms
# Speed: 1.2ms preprocess, 170.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.6ms
# Speed: 1.2ms preprocess, 175.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.3ms
# Speed: 1.2ms preprocess, 171.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.4ms
# Speed: 1.4ms preprocess, 170.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.4ms
# Speed: 1.3ms preprocess, 177.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.9ms
# Speed: 1.1ms preprocess, 167.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 178.0ms
# Speed: 1.2ms preprocess, 178.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# # Classes
# names:
#   0: person
#   1: bicycle
#   2: car
#   3: motorcycle
#   4: airplane
#   5: bus
#   6: train
#   7: truck
#   8: boat
#   9: traffic light
#   10: fire hydrant
#   11: stop sign
#   12: parking meter
#   13: bench
#   14: bird
#   15: cat
#   16: dog
#   17: horse
#   18: sheep
#   19: cow
#   20: elephant
#   21: bear
#   22: zebra
#   23: giraffe
#   24: backpack
#   25: umbrella
#   26: handbag
#   27: tie
#   28: suitcase
#   29: frisbee
#   30: skis
#   31: snowboard
#   32: sports ball
#   33: kite
#   34: baseball bat
#   35: baseball glove
#   36: skateboard
#   37: surfboard
#   38: tennis racket
#   39: bottle
#   40: wine glass
#   41: cup
#   42: fork
#   43: knife
#   44: spoon
#   45: bowl
#   46: banana
#   47: apple
#   48: sandwich
#   49: orange
#   50: broccoli
#   51: carrot
#   52: hot dog
#   53: pizza
#   54: donut
#   55: cake
#   56: chair
#   57: couch
#   58: potted plant
#   59: bed
#   60: dining table
#   61: toilet
#   62: tv
#   63: laptop
#   64: mouse
#   65: remote
#   66: keyboard
#   67: cell phone
#   68: microwave
#   69: oven
#   70: toaster
#   71: sink
#   72: refrigerator
#   73: book
#   74: clock
#   75: vase
#   76: scissors
#   77: teddy bear
#   78: hair drier
#   79: toothbrush
