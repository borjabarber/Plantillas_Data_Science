# %%
import cv2
import time
import numpy as np
from ultralytics import YOLO

# Cargar el modelo YOLOv11 (para detección de objetos)
model = YOLO("yolo11n")

# Definir la fuente de video 
cap = cv2.VideoCapture(0) # En directo
# video_path = './rutadelvideo'
# cap = cv2.VideoCapture(video_path) # De un archivo 

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Medir el tiempo de procesamiento para calcular la latencia
    start_time = time.time()
    
    # Realizar la detección (el modelo de segmentación también hace detección)
    results = model(
        frame, 
        conf=0.7, # solo muestra lo que esta seguro al 70%
        # classes=[0] # Si solo quieres detectar ciertas clases, por ejemplo, 'persona' (clase 0)
    )
    latency = (time.time() - start_time) * 1000  # Latencia en milisegundos

    # Acceder a las detecciones (bounding boxes)
    boxes_obj = results[0].boxes
    if boxes_obj is not None and len(boxes_obj) > 0:
        bboxes = boxes_obj.xyxy.cpu().numpy()    # Coordenadas [x1, y1, x2, y2]
        confs = boxes_obj.conf.cpu().numpy()      # Puntajes de confianza
        classes = boxes_obj.cls.cpu().numpy()     # Índices de clase
        
        # Iterar sobre cada detección y dibujar el bounding box y la etiqueta
        for i, box in enumerate(bboxes):
            x1, y1, x2, y2 = map(int, box)
            
            # Obtener el nombre de la clase
            class_name = model.names[int(classes[i])] if hasattr(model, 'names') else str(int(classes[i]))
            
            # Crear la etiqueta con el nombre de la clase y la confianza
            label = f'{class_name} {confs[i]:.2f}'
            
            # Dibujar el bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2) # Rojo, grosor 2
            
            # Dibujar la etiqueta encima del bounding box
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

    # Mostrar la latencia en el frame
    cv2.putText(frame, f'Latency: {latency:.1f}ms', (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)

    # Mostrar el frame procesado en tiempo real
    cv2.imshow("YOLOv11 - Detección de Objetos", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 79.7ms
# Speed: 2.5ms preprocess, 79.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.5ms
# Speed: 2.1ms preprocess, 78.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 83.8ms
# Speed: 2.4ms preprocess, 83.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.6ms
# Speed: 1.7ms preprocess, 80.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 82.6ms
# Speed: 1.3ms preprocess, 82.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 84.9ms
# Speed: 1.2ms preprocess, 84.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 81.2ms
# Speed: 1.3ms preprocess, 81.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 86.4ms
# Speed: 1.8ms preprocess, 86.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.7ms
# Speed: 1.8ms preprocess, 76.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 78.2ms
# Speed: 1.4ms preprocess, 78.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.7ms
# Speed: 2.2ms preprocess, 76.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.6ms
# Speed: 1.3ms preprocess, 77.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.0ms
# Speed: 1.2ms preprocess, 72.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.6ms
# Speed: 1.2ms preprocess, 62.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.3ms
# Speed: 1.1ms preprocess, 60.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.1ms
# Speed: 1.2ms preprocess, 64.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.8ms
# Speed: 1.3ms preprocess, 70.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.8ms
# Speed: 1.2ms preprocess, 55.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.6ms
# Speed: 1.3ms preprocess, 66.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.3ms
# Speed: 1.1ms preprocess, 57.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.6ms
# Speed: 1.2ms preprocess, 73.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.2ms
# Speed: 1.3ms preprocess, 63.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.6ms
# Speed: 1.2ms preprocess, 70.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.6ms
# Speed: 1.2ms preprocess, 63.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.7ms
# Speed: 1.7ms preprocess, 68.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.0ms
# Speed: 1.7ms preprocess, 71.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.6ms
# Speed: 1.6ms preprocess, 74.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.7ms
# Speed: 1.2ms preprocess, 74.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.4ms
# Speed: 1.7ms preprocess, 77.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.4ms
# Speed: 1.3ms preprocess, 75.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.7ms
# Speed: 1.9ms preprocess, 76.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.6ms
# Speed: 1.3ms preprocess, 74.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.6ms
# Speed: 1.6ms preprocess, 80.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.3ms
# Speed: 1.4ms preprocess, 77.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 86.7ms
# Speed: 1.2ms preprocess, 86.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.6ms
# Speed: 1.2ms preprocess, 77.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.7ms
# Speed: 1.2ms preprocess, 69.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.6ms
# Speed: 1.2ms preprocess, 66.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.4ms
# Speed: 1.2ms preprocess, 65.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.6ms
# Speed: 1.5ms preprocess, 62.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.6ms
# Speed: 1.3ms preprocess, 60.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.5ms
# Speed: 1.2ms preprocess, 54.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.1ms
# Speed: 1.5ms preprocess, 55.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.6ms
# Speed: 1.1ms preprocess, 66.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.3ms
# Speed: 1.1ms preprocess, 65.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.6ms
# Speed: 2.0ms preprocess, 70.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.3ms
# Speed: 1.2ms preprocess, 62.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.5ms
# Speed: 1.2ms preprocess, 65.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.2ms
# Speed: 1.3ms preprocess, 67.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.5ms
# Speed: 1.3ms preprocess, 74.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.4ms
# Speed: 1.3ms preprocess, 73.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.7ms
# Speed: 1.4ms preprocess, 69.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.3ms
# Speed: 1.8ms preprocess, 75.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 79.0ms
# Speed: 1.4ms preprocess, 79.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 85.1ms
# Speed: 1.2ms preprocess, 85.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 79.2ms
# Speed: 1.4ms preprocess, 79.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.5ms
# Speed: 1.2ms preprocess, 74.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.1ms
# Speed: 1.4ms preprocess, 77.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 70.0ms
# Speed: 1.7ms preprocess, 70.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 61.5ms
# Speed: 1.3ms preprocess, 61.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 63.1ms
# Speed: 1.4ms preprocess, 63.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.4ms
# Speed: 1.1ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 59.3ms
# Speed: 1.4ms preprocess, 59.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 62.6ms
# Speed: 1.2ms preprocess, 62.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 56.3ms
# Speed: 1.1ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.3ms
# Speed: 1.2ms preprocess, 60.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 56.8ms
# Speed: 1.3ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 62.9ms
# Speed: 1.1ms preprocess, 62.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 56.7ms
# Speed: 1.2ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.9ms
# Speed: 1.2ms preprocess, 55.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 59.9ms
# Speed: 1.2ms preprocess, 59.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.9ms
# Speed: 1.3ms preprocess, 61.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.6ms
# Speed: 1.3ms preprocess, 56.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.7ms
# Speed: 1.3ms preprocess, 61.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 78.7ms
# Speed: 1.9ms preprocess, 78.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.5ms
# Speed: 1.3ms preprocess, 59.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.0ms
# Speed: 1.2ms preprocess, 60.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.1ms
# Speed: 1.1ms preprocess, 68.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.9ms
# Speed: 1.8ms preprocess, 63.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.8ms
# Speed: 1.3ms preprocess, 68.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.5ms
# Speed: 1.3ms preprocess, 62.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.4ms
# Speed: 1.3ms preprocess, 61.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.7ms
# Speed: 1.5ms preprocess, 60.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.9ms
# Speed: 1.4ms preprocess, 58.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.3ms
# Speed: 1.5ms preprocess, 59.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.4ms
# Speed: 1.2ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.0ms
# Speed: 1.2ms preprocess, 55.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.8ms
# Speed: 1.2ms preprocess, 56.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.9ms
# Speed: 1.2ms preprocess, 54.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.8ms
# Speed: 1.2ms preprocess, 49.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.3ms
# Speed: 1.3ms preprocess, 62.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.6ms
# Speed: 1.3ms preprocess, 57.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.6ms
# Speed: 1.5ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.4ms
# Speed: 1.1ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.0ms
# Speed: 1.2ms preprocess, 69.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.5ms
# Speed: 1.1ms preprocess, 57.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.9ms
# Speed: 1.3ms preprocess, 59.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.9ms
# Speed: 1.2ms preprocess, 54.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.7ms
# Speed: 1.5ms preprocess, 57.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.9ms
# Speed: 1.5ms preprocess, 61.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 56.4ms
# Speed: 1.3ms preprocess, 56.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.2ms
# Speed: 1.1ms preprocess, 56.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.9ms
# Speed: 1.3ms preprocess, 57.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.2ms
# Speed: 1.3ms preprocess, 71.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.8ms
# Speed: 1.2ms preprocess, 57.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.5ms
# Speed: 1.5ms preprocess, 52.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.0ms
# Speed: 1.7ms preprocess, 63.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.1ms
# Speed: 1.3ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.5ms
# Speed: 1.4ms preprocess, 57.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.7ms
# Speed: 1.3ms preprocess, 63.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.2ms
# Speed: 1.6ms preprocess, 59.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 55.3ms
# Speed: 1.2ms preprocess, 55.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.7ms
# Speed: 1.2ms preprocess, 58.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 69.1ms
# Speed: 1.2ms preprocess, 69.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.2ms
# Speed: 1.3ms preprocess, 51.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.1ms
# Speed: 1.0ms preprocess, 54.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.7ms
# Speed: 1.1ms preprocess, 64.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 58.9ms
# Speed: 1.2ms preprocess, 58.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 52.9ms
# Speed: 1.2ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 55.3ms
# Speed: 1.4ms preprocess, 55.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 60.9ms
# Speed: 1.3ms preprocess, 60.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 68.1ms
# Speed: 1.3ms preprocess, 68.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 58.2ms
# Speed: 1.2ms preprocess, 58.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 57.7ms
# Speed: 1.2ms preprocess, 57.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 67.1ms
# Speed: 1.4ms preprocess, 67.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 58.1ms
# Speed: 1.2ms preprocess, 58.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.9ms
# Speed: 1.2ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 69.7ms
# Speed: 1.2ms preprocess, 69.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 73.9ms
# Speed: 1.4ms preprocess, 73.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.4ms
# Speed: 1.2ms preprocess, 62.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 75.9ms
# Speed: 1.3ms preprocess, 75.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.4ms
# Speed: 1.2ms preprocess, 64.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.8ms
# Speed: 1.3ms preprocess, 62.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.4ms
# Speed: 1.1ms preprocess, 62.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 remote, 61.1ms
# Speed: 1.1ms preprocess, 61.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 remote, 60.2ms
# Speed: 1.2ms preprocess, 60.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.4ms
# Speed: 1.1ms preprocess, 57.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.4ms
# Speed: 1.2ms preprocess, 54.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.2ms
# Speed: 1.1ms preprocess, 59.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.7ms
# Speed: 1.2ms preprocess, 53.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.1ms
# Speed: 1.1ms preprocess, 62.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.6ms
# Speed: 1.3ms preprocess, 63.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.9ms
# Speed: 1.6ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 57.7ms
# Speed: 1.4ms preprocess, 57.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 49.3ms
# Speed: 1.1ms preprocess, 49.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.5ms
# Speed: 1.1ms preprocess, 61.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.4ms
# Speed: 1.2ms preprocess, 64.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.6ms
# Speed: 1.5ms preprocess, 63.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.1ms
# Speed: 1.3ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.6ms
# Speed: 1.3ms preprocess, 58.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.2ms
# Speed: 1.4ms preprocess, 77.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.2ms
# Speed: 1.2ms preprocess, 67.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.7ms
# Speed: 1.9ms preprocess, 62.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.8ms
# Speed: 1.2ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.9ms
# Speed: 1.2ms preprocess, 66.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.0ms
# Speed: 1.5ms preprocess, 74.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.7ms
# Speed: 1.1ms preprocess, 67.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.4ms
# Speed: 1.6ms preprocess, 65.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.7ms
# Speed: 1.1ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.7ms
# Speed: 1.3ms preprocess, 62.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.9ms
# Speed: 1.6ms preprocess, 65.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 85.1ms
# Speed: 1.3ms preprocess, 85.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.4ms
# Speed: 1.3ms preprocess, 68.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.6ms
# Speed: 1.4ms preprocess, 61.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.1ms
# Speed: 1.1ms preprocess, 53.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.7ms
# Speed: 1.3ms preprocess, 56.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.4ms
# Speed: 1.3ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.7ms
# Speed: 1.3ms preprocess, 53.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.5ms
# Speed: 1.2ms preprocess, 54.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.8ms
# Speed: 1.1ms preprocess, 54.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.2ms
# Speed: 1.1ms preprocess, 62.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.6ms
# Speed: 1.4ms preprocess, 56.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.3ms
# Speed: 1.6ms preprocess, 57.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.0ms
# Speed: 1.1ms preprocess, 47.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.2ms
# Speed: 1.2ms preprocess, 63.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.5ms
# Speed: 1.3ms preprocess, 62.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.4ms
# Speed: 1.3ms preprocess, 65.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.1ms
# Speed: 1.3ms preprocess, 61.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.8ms
# Speed: 1.2ms preprocess, 66.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.8ms
# Speed: 1.5ms preprocess, 68.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.2ms
# Speed: 1.2ms preprocess, 69.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.4ms
# Speed: 1.3ms preprocess, 67.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.4ms
# Speed: 1.4ms preprocess, 59.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.7ms
# Speed: 1.2ms preprocess, 53.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.0ms
# Speed: 1.2ms preprocess, 54.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.8ms
# Speed: 1.1ms preprocess, 51.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.7ms
# Speed: 1.3ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.6ms
# Speed: 1.2ms preprocess, 60.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.5ms
# Speed: 1.6ms preprocess, 51.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.9ms
# Speed: 1.4ms preprocess, 63.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.5ms
# Speed: 1.6ms preprocess, 59.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.9ms
# Speed: 1.3ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.0ms
# Speed: 1.4ms preprocess, 58.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.4ms
# Speed: 1.3ms preprocess, 61.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.5ms
# Speed: 1.4ms preprocess, 57.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.2ms
# Speed: 1.3ms preprocess, 57.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.6ms
# Speed: 1.3ms preprocess, 58.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.7ms
# Speed: 1.3ms preprocess, 68.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.7ms
# Speed: 1.4ms preprocess, 62.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.8ms
# Speed: 1.2ms preprocess, 67.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.7ms
# Speed: 1.1ms preprocess, 64.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.7ms
# Speed: 1.1ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.2ms
# Speed: 1.3ms preprocess, 62.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.1ms
# Speed: 1.3ms preprocess, 62.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.7ms
# Speed: 1.3ms preprocess, 59.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.9ms
# Speed: 1.3ms preprocess, 72.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.0ms
# Speed: 1.2ms preprocess, 62.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.2ms
# Speed: 1.2ms preprocess, 58.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.6ms
# Speed: 1.2ms preprocess, 55.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.2ms
# Speed: 1.1ms preprocess, 54.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.1ms
# Speed: 1.4ms preprocess, 52.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.2ms
# Speed: 1.5ms preprocess, 54.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.0ms
# Speed: 1.1ms preprocess, 53.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.1ms
# Speed: 1.1ms preprocess, 52.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.1ms
# Speed: 1.3ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.2ms
# Speed: 1.2ms preprocess, 52.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.2ms
# Speed: 1.2ms preprocess, 58.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.0ms
# Speed: 1.4ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.0ms
# Speed: 1.5ms preprocess, 60.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.5ms
# Speed: 1.3ms preprocess, 55.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.8ms
# Speed: 1.2ms preprocess, 77.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 81.7ms
# Speed: 1.3ms preprocess, 81.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.6ms
# Speed: 1.3ms preprocess, 69.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.7ms
# Speed: 1.2ms preprocess, 60.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.3ms
# Speed: 1.4ms preprocess, 68.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.4ms
# Speed: 1.2ms preprocess, 71.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.9ms
# Speed: 1.2ms preprocess, 59.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.4ms
# Speed: 1.2ms preprocess, 64.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.7ms
# Speed: 1.2ms preprocess, 70.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.4ms
# Speed: 1.6ms preprocess, 62.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.6ms
# Speed: 1.3ms preprocess, 59.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.5ms
# Speed: 1.1ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.5ms
# Speed: 1.2ms preprocess, 61.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.9ms
# Speed: 1.1ms preprocess, 63.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.0ms
# Speed: 1.2ms preprocess, 56.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.2ms
# Speed: 1.3ms preprocess, 55.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.9ms
# Speed: 1.2ms preprocess, 56.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.4ms
# Speed: 1.2ms preprocess, 61.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.1ms
# Speed: 1.3ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.2ms
# Speed: 1.2ms preprocess, 65.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.7ms
# Speed: 1.3ms preprocess, 59.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.0ms
# Speed: 1.2ms preprocess, 55.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.4ms
# Speed: 1.1ms preprocess, 64.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.5ms
# Speed: 1.2ms preprocess, 59.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.3ms
# Speed: 2.2ms preprocess, 66.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.1ms
# Speed: 1.2ms preprocess, 57.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.1ms
# Speed: 1.2ms preprocess, 64.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.9ms
# Speed: 1.5ms preprocess, 64.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.1ms
# Speed: 1.2ms preprocess, 58.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.8ms
# Speed: 1.1ms preprocess, 57.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.3ms
# Speed: 1.2ms preprocess, 68.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.2ms
# Speed: 1.2ms preprocess, 67.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.8ms
# Speed: 1.2ms preprocess, 70.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.6ms
# Speed: 1.4ms preprocess, 61.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.1ms
# Speed: 1.2ms preprocess, 63.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.0ms
# Speed: 3.6ms preprocess, 76.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.5ms
# Speed: 1.3ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.3ms
# Speed: 1.2ms preprocess, 55.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.7ms
# Speed: 1.2ms preprocess, 54.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.7ms
# Speed: 1.1ms preprocess, 53.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.7ms
# Speed: 1.1ms preprocess, 55.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.2ms
# Speed: 1.1ms preprocess, 52.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.1ms
# Speed: 1.2ms preprocess, 49.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.9ms
# Speed: 1.3ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.4ms
# Speed: 1.1ms preprocess, 61.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.7ms
# Speed: 1.7ms preprocess, 71.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.6ms
# Speed: 1.4ms preprocess, 69.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.4ms
# Speed: 1.1ms preprocess, 63.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.8ms
# Speed: 1.1ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 59.4ms
# Speed: 1.2ms preprocess, 59.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.0ms
# Speed: 1.2ms preprocess, 68.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.6ms
# Speed: 1.1ms preprocess, 74.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.8ms
# Speed: 1.1ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.5ms
# Speed: 1.1ms preprocess, 61.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.8ms
# Speed: 1.5ms preprocess, 69.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.8ms
# Speed: 1.5ms preprocess, 70.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.7ms
# Speed: 1.3ms preprocess, 63.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.6ms
# Speed: 1.2ms preprocess, 61.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.6ms
# Speed: 1.3ms preprocess, 73.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.3ms
# Speed: 1.4ms preprocess, 62.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.6ms
# Speed: 1.2ms preprocess, 64.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.0ms
# Speed: 1.3ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.5ms
# Speed: 1.1ms preprocess, 63.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.8ms
# Speed: 1.3ms preprocess, 58.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.3ms
# Speed: 1.2ms preprocess, 61.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.5ms
# Speed: 1.3ms preprocess, 58.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.3ms
# Speed: 1.2ms preprocess, 52.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.3ms
# Speed: 1.4ms preprocess, 57.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.8ms
# Speed: 1.3ms preprocess, 53.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.3ms
# Speed: 1.2ms preprocess, 59.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.8ms
# Speed: 1.3ms preprocess, 63.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.1ms
# Speed: 1.4ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.3ms
# Speed: 1.2ms preprocess, 61.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.9ms
# Speed: 1.1ms preprocess, 63.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.1ms
# Speed: 1.3ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.9ms
# Speed: 1.2ms preprocess, 53.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.5ms
# Speed: 1.3ms preprocess, 76.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 69.4ms
# Speed: 1.1ms preprocess, 69.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.9ms
# Speed: 1.4ms preprocess, 68.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.1ms
# Speed: 1.3ms preprocess, 63.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.8ms
# Speed: 1.1ms preprocess, 64.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.7ms
# Speed: 1.2ms preprocess, 70.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.2ms
# Speed: 1.2ms preprocess, 59.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.0ms
# Speed: 1.3ms preprocess, 67.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.8ms
# Speed: 1.3ms preprocess, 72.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.1ms
# Speed: 1.6ms preprocess, 64.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.1ms
# Speed: 1.4ms preprocess, 58.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.0ms
# Speed: 1.2ms preprocess, 60.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.0ms
# Speed: 1.2ms preprocess, 56.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.7ms
# Speed: 1.1ms preprocess, 51.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.5ms
# Speed: 1.1ms preprocess, 50.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.6ms
# Speed: 1.3ms preprocess, 53.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.9ms
# Speed: 1.1ms preprocess, 50.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.4ms
# Speed: 1.2ms preprocess, 61.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.2ms
# Speed: 1.2ms preprocess, 62.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.9ms
# Speed: 1.3ms preprocess, 57.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.0ms
# Speed: 1.5ms preprocess, 54.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.5ms
# Speed: 1.2ms preprocess, 58.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.4ms
# Speed: 1.1ms preprocess, 63.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.0ms
# Speed: 1.2ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.3ms
# Speed: 1.3ms preprocess, 80.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.5ms
# Speed: 1.1ms preprocess, 70.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.4ms
# Speed: 1.3ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.8ms
# Speed: 1.2ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.1ms
# Speed: 1.1ms preprocess, 62.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.9ms
# Speed: 1.2ms preprocess, 72.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.7ms
# Speed: 1.4ms preprocess, 63.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.6ms
# Speed: 1.2ms preprocess, 70.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.2ms
# Speed: 2.7ms preprocess, 75.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.0ms
# Speed: 1.2ms preprocess, 68.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.5ms
# Speed: 1.2ms preprocess, 62.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.7ms
# Speed: 1.1ms preprocess, 56.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.1ms
# Speed: 1.2ms preprocess, 65.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.0ms
# Speed: 1.2ms preprocess, 61.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.2ms
# Speed: 1.1ms preprocess, 56.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.9ms
# Speed: 1.2ms preprocess, 56.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.4ms
# Speed: 1.3ms preprocess, 57.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.1ms
# Speed: 1.1ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.1ms
# Speed: 1.5ms preprocess, 62.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.6ms
# Speed: 1.1ms preprocess, 57.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# # Classes
# names:
#   0: person
#   1: bicycle
#   2: car
#   3: motorcycle
#   4: airplane
#   5: bus
#   6: train
#   7: truck
#   8: boat
#   9: traffic light
#   10: fire hydrant
#   11: stop sign
#   12: parking meter
#   13: bench
#   14: bird
#   15: cat
#   16: dog
#   17: horse
#   18: sheep
#   19: cow
#   20: elephant
#   21: bear
#   22: zebra
#   23: giraffe
#   24: backpack
#   25: umbrella
#   26: handbag
#   27: tie
#   28: suitcase
#   29: frisbee
#   30: skis
#   31: snowboard
#   32: sports ball
#   33: kite
#   34: baseball bat
#   35: baseball glove
#   36: skateboard
#   37: surfboard
#   38: tennis racket
#   39: bottle
#   40: wine glass
#   41: cup
#   42: fork
#   43: knife
#   44: spoon
#   45: bowl
#   46: banana
#   47: apple
#   48: sandwich
#   49: orange
#   50: broccoli
#   51: carrot
#   52: hot dog
#   53: pizza
#   54: donut
#   55: cake
#   56: chair
#   57: couch
#   58: potted plant
#   59: bed
#   60: dining table
#   61: toilet
#   62: tv
#   63: laptop
#   64: mouse
#   65: remote
#   66: keyboard
#   67: cell phone
#   68: microwave
#   69: oven
#   70: toaster
#   71: sink
#   72: refrigerator
#   73: book
#   74: clock
#   75: vase
#   76: scissors
#   77: teddy bear
#   78: hair drier
#   79: toothbrush
